# %% [markdown]
# # Overview
# Using a daily updated global pandemic data set, we would perform exploratory analysis to find out the most impacted countries due to Pandemic.
# #### Understanding structure of data
#  - Identifying Continuous and Categorical data
#  - Correct the datatype for date column
#  - Identify top countries with highest covid cases and deaths
#  - Plot top countries with highest death %

# %%
# Load Libraries
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
# Read File
df = pd.read_csv("s3:/dsba-6190-sbacon8/covid-us-counties.csv")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\s3fs\core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     206             try:
# --> 207                 return await method(**additional_kwargs)
#     208             except S3_RETRYABLE_ERRORS as e:
#
# ~\Anaconda3\lib\site-packages\aiobotocore\client.py in _make_api_call(self, operation_name, api_params)
#     150             error_class = self.exceptions.from_code(error_code)
# --> 151             raise error_class(parsed_response, operation_name)
#     152         else:
#
# ClientError: An error occurred (403) when calling the HeadObject operation: Forbidden
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# <ipython-input-18-e91c1b4c5cf0> in <module>
#       1 # Read File
# ----> 2 df = pd.read_csv("s3:/dsba-6190-sbacon8/covid-us-counties.csv")
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     429     # See https://github.com/python/mypy/issues/1297
#     430     fp_or_buf, _, compression, should_close = get_filepath_or_buffer(
# --> 431         filepath_or_buffer, encoding, compression
#     432     )
#     433     kwds["compression"] = compression
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     183
#     184         return s3.get_filepath_or_buffer(
# --> 185             filepath_or_buffer, encoding=encoding, compression=compression, mode=mode
#     186         )
#     187
#
# ~\Anaconda3\lib\site-packages\pandas\io\s3.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#      46     mode: Optional[str] = None,
#      47 ) -> Tuple[IO, Optional[str], Optional[str], bool]:
# ---> 48     file, _fs = get_file_and_filesystem(filepath_or_buffer, mode=mode)
#      49     return file, None, compression, True
#
# ~\Anaconda3\lib\site-packages\pandas\io\s3.py in get_file_and_filesystem(filepath_or_buffer, mode)
#      36         # for that bucket.
#      37         fs = s3fs.S3FileSystem(anon=True)
# ---> 38         file = fs.open(_strip_schema(filepath_or_buffer), mode)
#      39     return file, fs
#      40
#
# ~\Anaconda3\lib\site-packages\fsspec\spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#     851                 autocommit=ac,
#     852                 cache_options=cache_options,
# --> 853                 **kwargs
#     854             )
#     855             if not ac:
#
# ~\Anaconda3\lib\site-packages\s3fs\core.py in _open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, requester_pays, **kwargs)
#     403                       version_id=version_id, fill_cache=fill_cache,
#     404                       s3_additional_kwargs=kw, cache_type=cache_type,
# --> 405                       autocommit=autocommit, requester_pays=requester_pays)
#     406
#     407     async def _lsdir(self, path, refresh=False, max_items=None, delimiter="/"):
#
# ~\Anaconda3\lib\site-packages\s3fs\core.py in __init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs, autocommit, cache_type, requester_pays)
#    1325         self.req_kw = {'RequestPayer': 'requester'} if requester_pays else {}
#    1326         super().__init__(s3, path, mode, block_size, autocommit=autocommit,
# -> 1327                          cache_type=cache_type)
#    1328         self.s3 = self.fs  # compatibility
#    1329         if self.writable():
#
# ~\Anaconda3\lib\site-packages\fsspec\spec.py in __init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, **kwargs)
#    1165         if mode == "rb":
#    1166             if not hasattr(self, "details"):
# -> 1167                 self.details = fs.info(path)
#    1168             self.size = self.details["size"]
#    1169             self.cache = caches[cache_type](
#
# ~\Anaconda3\lib\site-packages\s3fs\core.py in info(self, path, version_id, refresh)
#     768
#     769         if should_fetch_from_s3:
# --> 770             return maybe_sync(self._info, self, path, bucket, key, kwargs, version_id)
#     771         return super().info(path)
#     772
#
# ~\Anaconda3\lib\site-packages\fsspec\asyn.py in maybe_sync(func, self, *args, **kwargs)
#      94         if inspect.iscoroutinefunction(func):
#      95             # run the awaitable on the loop
# ---> 96             return sync(loop, func, *args, **kwargs)
#      97         else:
#      98             # just call the blocking function
#
# ~\Anaconda3\lib\site-packages\fsspec\asyn.py in sync(loop, func, callback_timeout, *args, **kwargs)
#      65     if error[0]:
#      66         typ, exc, tb = error[0]
# ---> 67         raise exc.with_traceback(tb)
#      68     else:
#      69         return result[0]
#
# ~\Anaconda3\lib\site-packages\fsspec\asyn.py in f()
#      49             if callback_timeout is not None:
#      50                 future = asyncio.wait_for(future, callback_timeout)
# ---> 51             result[0] = await future
#      52         except Exception:
#      53             error[0] = sys.exc_info()
#
# ~\Anaconda3\lib\site-packages\s3fs\core.py in _info(self, path, bucket, key, kwargs, version_id)
#     709         try:
#     710             out = await self._call_s3(self.s3.head_object, kwargs, Bucket=bucket,
# --> 711                                       Key=key, **version_id_kw(version_id), **self.req_kw)
#     712             return {
#     713                 'ETag': out['ETag'],
#
# ~\Anaconda3\lib\site-packages\s3fs\core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     223             except Exception as e:
#     224                 err = e
# --> 225         raise translate_boto_error(err) from err
#     226
#     227     call_s3 = sync_wrapper(_call_s3)
#
# PermissionError: Forbidden

# %%
# Read top 10 rows
df.head(10)

# %%
#Looking at all the variables and their types
df.info()
df.describe()

# %%
# Change the datatype of date column to datetime format
df['date']= pd.to_datetime(df['date']) 
df.info()

# %%
# Check if there are any missing values in the data
df.isna().sum()
# Note that there are missing values for fips

# %%
# Find states with highest no of Covid cases
df.groupby('state').sum().sort_values(by=['cases'], ascending=False).head(10)

# %%
# Find states with highest no of Covid death
df.groupby('state').sum().sort_values(by=['deaths'], ascending=False).head(10)

# %%
# Plot Cases vs deaths
plt.scatter(df['cases'], df['deaths'], alpha = 0.1)
plt.xlabel("Total Number of Cases")
plt.ylabel("Total Deaths")
plt.title("Total Number of Cases vs Total Deaths")

# %%
# Add new column of death % after aggregating the numerical columns
state_wise = df.groupby(["state"]).agg({"fips" : "sum", "cases" : "sum", "deaths" : "sum"})
state_wise["deaths %"] = (state_wise["deaths"]/state_wise["cases"])*100
state_wise.head(10)

# %%
# Plot the top states with most no of covid cases and high % of deaths
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (25, 10))
top_total_cases = state_wise.sort_values(["cases"], ascending = False).head(10)
top_total_deaths = state_wise.sort_values(["deaths %"], ascending = False).head(10)
sns.barplot(x = top_total_cases["cases"], y = top_total_cases.index, ax = ax1)
ax1.set_title("Top States with most no of Covid Cases")
sns.barplot(x = top_total_deaths["deaths %"], y = top_total_deaths.index, ax = ax2)
ax2.set_title("Top States with high % of Covid deaths")

plt.show()

# %%
import socket
print(socket.gethostname())

# %%
# !aws configure list
